# %% [markdown]
# # Lab 07

# %% [markdown]
# ## Zadanie 1

# %% [markdown]
# Przygotuj demo programu znajdującego miejsca zerowe metodą Newtona. Wykorzystując `argparse` ([link](https://docs.python.org/3.6/library/argparse.html#module-argparse)) lub `optparse` ([link](https://docs.python.org/3.6/library/optparse.html)) obsłuż:
# - ustalane punktu startowego,
# - wielkość kroku w pochodnej,
# - ilość kroków metody,
# - dokładność
# - pomoc
#
# Program uruchamiamy podając, np.:

# %% [markdown]
# `./newton.py x**2+x+1 -h 0.00001`

# %%
# !python newton.py "x**2 + 2*x + 1" -s 0.5 1000 -t 1e-5
# Out:
# Znaleziono miejsce zerowe: x = -0.9980907440+0.0000000000j, w 20 krokach.

# %% [markdown]
# ## Zadanie 2

# %% [markdown]
# Zadanie należy wykonać wykorzystując program `BagOfWords` z poprzednich zajęć.
#
#
# Przerób ją tak, żeby interpunkcja, cyfry i wszelkie inne znaki nie przeszkadzały w parsowaniu tekstu. Uruchom ja na [tekście hamleta](http://www.gutenberg.org/cache/epub/1787/pg1787.txt). Ile razy występuje słowo hamlet? Jak brzmi 10 najczęściej występujących słów?

# %%
import re
from collections import Counter

class BagOfWords:
    def __init__(self, source):
        if isinstance(source, str):
            text = source
        else:
            text = source.read()
        
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        words = text.lower().split()        
        self.word_counts = Counter(words)

    def __str__(self):
        return ", ".join(f"{word}:{count}" for word, count in self.word_counts.most_common())

    def __contains__(self, word):
        return word in self.word_counts

    def __iter__(self):
        for word, _ in self.word_counts.most_common():
            yield word

    def __add__(self, other):
        if not isinstance(other, BagOfWords):
            raise TypeError("Can only add BagOfWords instances.")
        combined = BagOfWords("")
        combined.word_counts = self.word_counts + other.word_counts
        return combined

    def __getitem__(self, word):
        return self.word_counts.get(word, 0)

    def __setitem__(self, word, count):
        self.word_counts[word] = count

# %%
with open("hamlet.txt", encoding="utf-8") as file:
    hamlet = BagOfWords(file)
    
print("Liczba słów 'hamlet': ", hamlet["hamlet"])
print("10 najpopularniejszych słów: ")
for word, count in hamlet.word_counts.most_common(10):
    print(f"{word}: {count}")
# Out:
# Liczba słów 'hamlet':  115
# 10 najpopularniejszych słów:
# the: 1349
# and: 1101
# of: 887
# to: 863
# you: 660
# a: 633
# i: 575
# my: 520
# in: 503
# it: 445

# %% [markdown]
# ## Zadanie 3

# %% [markdown]
# Wykorzystując `pickle` zapisz i odczytaj klasy z poprzedniego zadania nakarmonej Hamletem. Porównaj metody i rozmiar.

# %%
import pickle

with open('data.pkl', 'wb') as f:
    pickle.dump(hamlet, f)

with open('data.pkl', 'rb') as f:
    data_loaded = pickle.load(f)

print(hamlet)
print(data_loaded)
# Out:
:19, believe:19, hand:19, blood:19, aside:19, makes:19, used:18, welcome:18, thing:18, ist:18, young:18, little:18, theres:18, agreement:18, readable:17, free:17, please:17, right:17, farewell:17, art:17, find:17, thoughts:17, noble:17, body:17, ear:17, sword:17, version:16, charges:16, gentleman:16, daughter:16, live:16, thats:16, question:16, majesty:16, hast:16, faith:16, youth:16, marry:16, speech:16, ebook:15, united:15, copy:15, inc:15, has:15, machine:15, last:15, law:15, university:15, including:15, word:15, purpose:15, fortinbras:15, gertrude:15, castle:15, stand:15, yourself:15, watch:15, therefore:15, mark:15, eye:15, bear:15, better:15, tongue:15, drink:15, while:15, said:15, between:15, after:15, help:15, personal:14, commercial:14, includes:14, further:14, trademark:14, each:14, ever:14, carnegie:14, mellon:14, second:14, kind:14, friend:14, answer:14, ho:14, charge:14, gone:14, something:14, goes:14, heard:14, spirit:14, oer:14, grief:14, things:14, reason:14, thine:14, forth:14, gentlemen:14, phrase:14, murther:14, sent:14, rest:14, lady:14, dost:14, sings:14, under:13, commercially:13, prohibited:13, download:13, membership:13, information:13, refund:13, norway:13, same:13, air:13, duty:13, lets:13, room:13, ourselves:13, sense:13, grace:13, none:13, virtue:13, way:13, another:13, rey:13, literary:13, archive:13, almost:12, laws:12, access:12, thousand:12, fee:12, receive:12, marcellus:12, haste:12, myself:12, together:12, stay:12, int:12, ere:1 ...

# %%
import os
print("Rozmiar pliku pickle: ", os.path.getsize('data.pkl'))
print("Rozmiar pliku oryginalnego hamlet: ", os.path.getsize('hamlet.txt'))
# Out:
# Rozmiar pliku pickle:  61205
# Rozmiar pliku oryginalnego hamlet:  230837

# %% [markdown]
# ## Zadanie 4

# %% [markdown]
# Wykorzystując [https://gist.github.com/pamelafox/986163](https://gist.github.com/pamelafox/986163) podaj aktualną godzinę we:
# - wszystkich krajach, wyświetlając je zgrupowane względem kontynentów,
# - przeprowadź symulacyjne wyświetlanie kolejnych krajów w miarę jak w danym kraju wybija północ, opóżnienie wyświetlania ustaw proporcjonalne do realnego czasu

# %%
from datetime import datetime
import re
import pytz
import time_zone

def group_by_continent():
    continent_dict = {"Europe" : [], "Asia" : [], "Africa" : [], "Oceania" : [], "North America" : [], "South America" : []}
    for elem in time_zone.countries:
        continent_dict[elem['continent']].append(elem)

    for cont in continent_dict:
        print(cont)
        for country in continent_dict[cont]:
            print("Time in", country['name'], "-", datetime.now(pytz.timezone(country['timezones'][0])).strftime('%Y-%m-%d %H:%M:%S'))

print(group_by_continent())
# Out:
# Europe
# Time in Andorra - 2025-01-11 22:02:55
# Time in Albania - 2025-01-11 22:02:55
# Time in Austria - 2025-01-11 22:02:55
# Time in Belgium - 2025-01-11 22:02:55
# Time in Bulgaria - 2025-01-11 23:02:55
# Time in Belarus - 2025-01-12 00:02:55
# Time in Czech Republic - 2025-01-11 22:02:55
# Time in Germany - 2025-01-11 22:02:55
# Time in Denmark - 2025-01-11 22:02:55
# Time in Venezuela - 2025-01-11 17:02:55
# None

# %% [markdown]
# ## Zadanie 5

# %% [markdown]
# Dla klasy `BagOfWords` napisz metody `save` oraz `load` wykorzystujące `json`'a do zapisu i odczytu danych.

# %%
import json
from collections import Counter

class BagOfWords:
    def __init__(self, source):
        if isinstance(source, str):
            words = source.split()
        else:
            words = source.read().split()
        self.word_counts = Counter(words)

    def __str__(self):
        return ", ".join(f"{word}:{count}" for word, count in self.word_counts.most_common())

    def __contains__(self, word):
        return word in self.word_counts

    def __iter__(self):
        for word, _ in self.word_counts.most_common():
            yield word

    def __add__(self, other):
        if not isinstance(other, BagOfWords):
            raise TypeError("Can only add BagOfWords instances.")
        combined = BagOfWords("")
        combined.word_counts = self.word_counts + other.word_counts
        return combined

    def __getitem__(self, word):
        return self.word_counts.get(word, 0)

    def __setitem__(self, word, count):
        self.word_counts[word] = count

    def save(self, filename):
        with open(filename, 'w', encoding='utf-8') as file:
            json.dump(self.word_counts, file, ensure_ascii=False, indent=4)

    @classmethod
    def load(cls, filename):
        """Ładuje dane BagOfWords z pliku JSON."""
        with open(filename, 'r', encoding='utf-8') as file:
            word_counts = json.load(file)
        bow = cls("")
        bow.word_counts = Counter(word_counts)
        return bow

# %%
with open("hamlet.txt", "r", encoding="utf-8") as file:
    hamlet_json = BagOfWords(file)

hamlet_json.save("hamlet.json")
new_obj = BagOfWords.load("hamlet.json")
print(new_obj)
# Out:
# the:1138, of:776, and:772, to:704, a:521, I:521, in:449, my:444, you:438, Ham.:358, is:340, not:286, it:284, his:284, with:274, And:259, this:253, that:246, your:234, be:214, for:196, The:177, have:169, or:168, as:156, he:151, me:144, are:143, but:142, will:141, by:131, To:125, do:123, him:121, That:118, our:116, But:116, King.:116, on:113, we:113, Hor.:108, shall:106, all:104, from:103, what:101, so:99, no:98, at:94, Project:93, A:90, What:90, Pol.:86, You:84, may:83, thou:83, thy:81, lord,:81, Queen.:78, most:75, My:75, they:74, If:72, was:72, more:71, good:71, For:70, As:70, her:68, like:67, Enter:66, must:65, if:63, It:63, would:62, Laer.:62, OF:61, lord.:61, This:60, th':60, O,:59, How:58, very:58, Oph.:58, know:57, should:56, an:56, I'll:56, hath:55, OR:54, such:54, you,:54, their:53, Gutenberg™:53, am:52, let:52, He:51, some:51, O:50, any:49, FOR:47, us:47, much:46, make:46, did:46, which:45, can:45, Ros.:45, come:44, them:44, Of:44, than:43, With:43, So:43, Let:43, it,:42, give:42, AND:41, out:41, upon:40, BY:39, We:39, In:39, love:39, work:38, think:37, had:37, there:37, 'Tis:36, now:36, speak:36, own:36, tell:36, you.:36, one:35, me.:35, thee:35, 'tis:35, these:35, go:35, she:35, other:34, how:34, King:34, it.:34, Ay,:34, Gutenberg:33, time:33, Or:33, Clown.:33, him.:32, too:32, man:32, Hamlet:31, where:31, up:31, Mar.:31, lord?:31, Hamlet,:30, ARE:30, When:30, me